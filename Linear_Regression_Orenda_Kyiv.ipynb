# %%
import pandas as pd

df = pd.read_csv('rieltor_subways_new2.csv')
df
# Out:
#                                               link  rooms    price  flat_area  \
# 0     https://rieltor.ua/flats-rent/view/10834307/    2.0  24500.0      109.0
# 1     https://rieltor.ua/flats-rent/view/10832872/    2.0  24500.0      112.0
# 2     https://rieltor.ua/flats-rent/view/10725408/    2.0  22000.0       94.0
# 3     https://rieltor.ua/flats-rent/view/10766471/    2.0  22000.0       82.0
# 4     https://rieltor.ua/flats-rent/view/10832868/    3.0  55410.0      161.0
# ...                                            ...    ...      ...        ...
# 5628  https://rieltor.ua/flats-rent/view/10620878/    1.0  16000.0       85.0
# 5629  https://rieltor.ua/flats-rent/view/10803998/    1.0   9500.0       64.0
# 5630   https://rieltor.ua/flats-rent/view/9615917/    2.0   6000.0       55.0
# 5631  https://rieltor.ua/flats-rent/view/10055853/    1.0   9000.0       89.0
# 5632  https://rieltor.ua/flats-rent/view/10548982/    2.0   7000.0       80.5
#
#       premium        district                                     address  \
# 0     ПРЕМІУМ      Дарницький                           Зарічна вул., 1-Б
# 1     ПРЕМІУМ      Дарницький                            Зарічна вул., 1б
# 2     ПРЕМІУМ      Печерський                    Лесі Українки бульв., 17
# 3     ПРЕМІУМ      Печерський                    Лесі Українки бульв., 17
# 4     ПРЕМІУМ      Печерський                     Предславинська вул., 42
# ...       ...             ...                                         ...
# 5628       no   Святошинський                    Крамського Івана вул., 9
# 5629       no   Святошинський               Кіпріанова академіка вул., 6А
# 5630       no  Шевченківський  Данила Щербаківського вул. (Щербакова), 54
# 5631       no   Святошинський                      Стуса Василя вул., 28а
# 5632       no    Дніпровський                      Гродненська вул., 3/5
#
#        latitude  longitude     subway  ...       type_of_house  \
# 0     50.395950  30.599648        NaN  ...    Українська цегла
# 1     50.395950  30.599648        NaN  ...    Українська цегла
# 2     50.429684  30.536922        NaN  ...         Стара цегла
# 3     50.429684  30.536922        NaN  ...                None
# 4     50.415512  30.525202  Либідська  ...    Українська цегла
# ...         ...        ...        ...  ...                 ...
# 5628  50.453461  30.372721        NaN  ...  Бетонно монолітний
# 5629  50.438808  30.379671        NaN  ...                None
# 5630  50.460178  30.402700        NaN  ...    Українська цегла
# 5631        NaN        NaN        NaN  ...       Типова панель
# 5632        NaN        NaN        NaN  ...         Стара цегла
#
#           type_of_rooms     type_of_condition prestigious  code type  \
# 0             Роздільне  Дизайнерський ремонт           1          5
# 1        Кухня-вітальня  Дизайнерський ремонт           1          5
# 2             Роздільне            Євроремонт           3          4
# 3             Роздільне  Дизайнерський ремонт           3          5
# 4             Роздільне            Євроремонт           3          4
# ...                 ...                   ...         ...        ...
# 5628          Роздільне            Євроремонт           1          4
# 5629          Роздільне            Євроремонт           1          4
# 5630          Роздільне          Хороший стан           3          3
# 5631          Роздільне      Задовільний стан           1          1
# 5632  Суміжно-роздільна          Чудовий стан           1          4
#
#       price_category   closest_subway       subway_location  \
# 0        20000-40000         Славутич  50.394167, 30.604167
# 1        20000-40000         Славутич  50.394167, 30.604167
# 2        20000-40000        Печерська    50.4275, 30.538889
# 3        20000-40000        Печерська    50.4275, 30.538889
# 4        40000-60000  Палац "Україна"  50.420833, 30.520833
# ...              ...              ...                   ...
# 5628     10000-20000      Житомирська  50.456175, 30.365628
# 5629      4000-10000      Житомирська  50.456175, 30.365628
# 5630      4000-10000            Нивки  50.458653, 30.404042
# 5631      4000-10000              NaN                   NaN
# 5632      4000-10000              NaN                   NaN
#
#      distance_to_subway  distance_category
# 0              0.376771                  1
# 1              0.376771                  1
# 2              0.279936                  1
# 3              0.279936                  1
# 4              0.667737                  1
# ...                 ...                ...
# 5628           0.585864                  1
# 5629           2.172046                  2
# 5630           0.194392                  1
# 5631           0.000000                  1
# 5632           0.000000                  1
#
# [5633 rows x 21 columns]

# %%
#Data Vocabulary of Features taken to analysis

#Rooms - quantity of rooms

#Price - price in hryvnas

#flat_area - area of a flat in square meters

#prestigious - code of districts:
#code_prestigious = {'Печерський': 3,
#                 'Шевченківський': 3,
#                 'Голосіївський': 3,
#                 'Подільський': 2,
#                 'Святошинський': 1,
#                 'Солом\'янський': 2,
#                 'Оболонський': 2,
#                 'Дніпровський': 1,
#                 'Дарницький': 1,
#                 'Деснянський': 1}
#
##code of prestigious districts accorting to task and our results:
# code_type = {'Дизайнерський ремонт': 5,
#                 'Євроремонт': 4,
#                 'Чудовий стан': 4,
#                 'Хороший стан': 3,
#                 'Задовільний стан': 1,
#                 'Перша здача': 2,
#                 'Потрібен капітальний ремонт': 1,
#                 'Незавершений ремонт': 1,
#                 'Потрібен косметичний ремонт': 1,
#                 'Від будівельників вільне планування': 1,
#                  'Незавершений ремонт': 1}

# %%
from sklearn.linear_model import LinearRegression

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
reg=LinearRegression()
reg
# Out:
# LinearRegression()

# %%
X=df[['rooms', 'flat_area', 'prestigious', 'distance_category', 'code type']]
y=df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_train, y_train)
# Out:
# 0.598870867381663

# %%
reg.score(X_test, y_test)
# Out:
# 0.6200420167286724

# %%
reg.predict([[1, 40, 2, 1, 3]])
# Out:
# C:\Users\liman\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8622.60407746])
